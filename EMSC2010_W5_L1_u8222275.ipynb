# %% [markdown]
# <a href="https://colab.research.google.com/github/Elpog1/EMSC2010-W5-L1/blob/main/EMSC2010_W5_L1_u8222275.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #EMSC2010-W5-L1
#
# ## Random numbers
# Below is some simple code to *generate uniformly* distributed random numbers. Don't worry about how the code works, we're just going to use it to demonstrate a concept.

# %%
class SimpleRNG:
    """
    A Linear Congruential Generator (LCG).
    Formula: next = (a * current + c) % m
    """
    def __init__(self, seed=42):
        self.state = seed
        self.a = 1664525      # Multiplier
        self.c = 1013904223   # Increment
        self.m = 2**32        # Modulus

    def next_int(self):
        """Generate the next raw integer."""
        self.state = (self.a * self.state + self.c) % self.m
        return self.state

    def next_float(self):
        """Generate a float in [0, 1)."""
        return self.next_int() / self.m

# %% [markdown]
# Generate 5 random numbers using a *seed* and print them to the screen

# %%
rng1 = SimpleRNG(seed=99)
for _ in range(5):
    print(f"  rng1: {rng1.next_float():.6f}")
# Out:
#   rng1: 0.274436
#   rng1: 0.258240
#   rng1: 0.605653
#   rng1: 0.332487
#   rng1: 0.364237

# %% [markdown]
# ### Using Numpy
# Rather than writing our own code, we typically use a package like ```numpy``` to generate random numbers.

# %%
import numpy as np

# Create a generator with a fixed seed
rng = np.random.default_rng(seed=99)

# Generate an array of 5 numbers in [0, 1)
print(rng.uniform(size=5))

# Generate numbers in a custom range, e.g. [10, 20)
print(rng.uniform(low=10, high=20, size=5))
# Out:
# [0.50603067 0.56509163 0.51191596 0.97218637 0.61490314]
# [15.68283498 12.86786723 15.54511453 14.67523526 16.10058008]

# %%
X = rng.uniform(size=100000)+10+10

# %%
import matplotlib.pyplot as plt
plt.hist(X, bins=50)
# Out:
# (array([15., 18., 14., 10., 21., 18., 18., 17., 19., 21., 22., 17., 26.,
#         23., 15., 21., 21., 22., 24., 22., 19., 23., 19., 13., 13., 15.,
#         21., 22., 26., 28., 19., 12., 25., 23., 13., 22., 22., 18., 27.,
#         24., 17., 16., 24., 19., 22., 27., 15., 17., 32., 23.]),
#  array([3.36519389e-04, 2.03235352e-02, 4.03105510e-02, 6.02975668e-02,
#         8.02845826e-02, 1.00271598e-01, 1.20258614e-01, 1.40245630e-01,
#         1.60232646e-01, 1.80219662e-01, 2.00206677e-01, 2.20193693e-01,
#         2.40180709e-01, 2.60167725e-01, 2.80154741e-01, 3.00141756e-01,
#         3.20128772e-01, 3.40115788e-01, 3.60102804e-01, 3.80089819e-01,
#         4.00076835e-01, 4.20063851e-01, 4.40050867e-01, 4.60037883e-01,
#         4.80024898e-01, 5.00011914e-01, 5.19998930e-01, 5.39985946e-01,
#         5.59972962e-01, 5.79959977e-01, 5.99946993e-01, 6.19934009e-01,
#         6.39921025e-01, 6.59908041e-01, 6.79895056e-01, 6.99882072e-01,
#         7.19869088e-01, 7.39856104e-01, 7.59843120e-01, 7.79830135e-01,
#         7.99817151e-01, 8.19804167e-01, 8.39791183e-01, 8.59778199e-01,
#         8.79765214e-01, 8.99752230e-01, 9.19739246e-01, 9.39726262e-01,
#         9.59713278e-01, 9.79700293e-01, 9.99687309e-01]),
#  <BarContainer object of 50 artists>)

# %%
Ntot = 1000
X = rng.uniform(size=Ntot)
Y = rng.uniform(size=Ntot)
plt.plot(X,Y,'.')

# %%
#Monte-Carlo simulation

# %%
Ntot = 1000000
X = rng.uniform(size=Ntot)
Y = rng.uniform(size=Ntot)
D = np.sqrt((X-0.5)**2 + (Y-0.5)**2)
Nc = np.sum(D<0.5)
print(Nc)
Ac = Nc/Ntot
print(Ac)
print(np.pi*0.5**2)
# Out:
# 785312
# 0.785312
# 0.7853981633974483
